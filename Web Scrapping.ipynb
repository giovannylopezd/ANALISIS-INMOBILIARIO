# %% [markdown]
# ##  Web Scrapping de Datos Inmobiliarios
#
# Realizado por: **Giovanny Lopez**

# %% [markdown]
# En este apartado realizaremos la extracción de datos inmobiliarios en la ciudad de Santa Cruz de la Sierra.
# La página que tomaremos, debido a su relevancia en la región, será [**Infocasas**](www.infocasas.com)

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %% [markdown]
# 1. Creamos la variable con el **URL** principal de la página que deseamos analizar.
# 2. Creamos un agente que imitará el ingreso de un humano a la página para poder acceder.
# 3. Creamos una lista vacía para llenarla de los links que dirigen a cada anuncio de venta de inmuebles

# %%
urlbase = 'https://www.infocasas.com.bo/'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'
}

link_casas = []

# %% [markdown]
# ### Anuncios de Venta de Inmuebles
# En este apartado necesitamos recabar la siguiente información:
# 1. Número de páginas que queremos buscar
# 2. **URL** de la segunda página para obtener un indicador de página
# 3. Elemento de bloque donde se enlista la información de cada anuncio **('div','span',etc.)**,la clase y
# verificar que contenga el elemento **'a'** con su respectivo enlace al anuncio en cada inmueble.
#
# Por último, al link obtenido en el **Paso 2** le añadimos una **f** (fstring) y reemplazamos el numero de página por **{x}**.
# *Es así que conseguimos los links de cada anuncio, los adicionamos a la lista e iteramos la operación para cada página*

# %%
pag = 30
for x in range(1,pag+1):
  r = requests.get(f'https://www.infocasas.com.bo/venta/casas-y-departamentos-y-condominio/santa-cruz/pagina{x}?&ordenListado=5', headers=headers)
  soup = BeautifulSoup(r.content, 'html.parser')
  lista_casas = soup.find_all('div', class_= 'propiedades-slider ')
  for item in lista_casas:
    for link in item.find_all('a', href=True):
      link_casas.append(urlbase + link['href'])

link_casas = set(link_casas) # Para eliminar los duplicados
print(len(link_casas))
# Out:
# 897

# %% [markdown]
# ### Datos de interés
# Para esto necesitamos ingresar a uno de los anuncios y recabar la información que más nos interese y que pueda estar en la mayoría de los anuncios.
#
# Los pasos son los siguientes:
# 1. Inspeccionamos los datos de interés y ubicamos el elemento de bloque que los contiene junto a la clase
# 2. Damos un formato al texto obtenido según nuestra conveniencia
# 3. Ingresamos un **try** y un **except** para poder manejar el blucle en caso de error por falta de datos.
# 4. Creamos un diccionario que contenga todas las variables que hemos especificado en el bucle.
# 5. Agregamos datos de cada inmueble por cada iteración de nuestro bucle en nuestra lista creada al principio

# %%
lista_items = []
for link in link_casas:
    r = requests.get(link, headers=headers)
    soup = BeautifulSoup(r.content,'lxml')
    
    try:
        tipo = soup.find('div', class_='dot home').text.strip()
        tipo = tipo.replace('Tipo de propiedad\n\n','')
    except:
        tipo = 'NA'
    
    try:
        dormitorios = soup.find('div', class_='dot bed').text.strip()
        dormitorios = re.sub("[^0-9]", "", dormitorios)
    except:
        dormitorios = 'NA'
    try:
        baños = soup.find('div', class_='dot shower').text.strip()
        baños = re.sub("[^0-9]", "", baños)
    except:
        baños = 'NA'
    
    try:
        garajes = soup.find('div', class_='dot cab').text.strip()
        garajes = re.sub("[^0-9]", "", garajes)
    except:
        garajes = str(0)
    
    try:
        m2 = soup.find('div', class_='dot m2').text.strip()
        m2 = re.sub("[^0-9]", "", m2)
    except:
        m2 = 'NA'
    
    try:
        precio = soup.find('p', class_='precio-final').text.strip()
        precio = precio.replace('U$S ','')
    except:
        precio = 'NA'
    
    try:
        titulo = soup.find('h1', class_='likeh2 titulo one-line-txt').text.strip()
    except:
        titulo = 'NA'
    
    try:
        zona = soup.find('p', class_='zona-nombre').text.strip()    
    except:
        zona = 'NA'
    
    casas = {
        'titulo': titulo,
        'tipo': tipo,
        'dormitorios': dormitorios,
        'baños': baños,
        'garajes': garajes,
        'm2': m2,
        'zona': zona,
        'precio': precio
        }
    
    lista_items.append(casas)
    print('Guardando: Inmueble', len(lista_items),'zona ',casas['zona'])
# Out:
# Guardando: Inmueble 1 zona  Norte
# Guardando: Inmueble 2 zona  Urubó
# Guardando: Inmueble 3 zona  Sur
# Guardando: Inmueble 4 zona  Oeste
# Guardando: Inmueble 5 zona  Urubó
# Guardando: Inmueble 6 zona  NA
# Guardando: Inmueble 7 zona  Norte / Remanso
# Guardando: Inmueble 8 zona  Norte
# Guardando: Inmueble 9 zona  Norte / Equipetrol
# Guardando: Inmueble 10 zona  Centro
# Guardando: Inmueble 11 zona  Oeste
# Guardando: Inmueble 12 zona  Este
# Guardando: Inmueble 13 zona  Centro
# Guardando: Inmueble 14 zona  Norte
# Guardando: Inmueble 15 zona  Urubó
# Guardando: Inmueble 16 zona  Urubó
# Guardando: Inmueble 17 zona  Sur
# Guardando: Inmueble 18 zona  Urubó
# Guardando: Inmueble 19 zona  Norte
# Guardando: Inmueble 20 zona  Este
# Guardando: Inmueble 21 zona  Oeste
# Guardando: Inmueble 22 zona  Norte
# Guardando: Inmueble 23 zona  Sur
# Guardando: Inmueble 24 zona  Oeste
# Guardando: Inmueble 25 zona  Centro
# Guardando: Inmueble 26 zona  Norte / Equipetrol
# Guardando: Inmueble 27 zona  Norte
# Guardando: Inmueble 28 zona  Este
# Guardando: Inmueble 29 zona  Urubó
# Guardando: Inmueble 30 zona  Este
# Guardando: Inmueble 31 zona  Oeste
# Guardando: Inmueble 32 zona  Urubó
# Guardando: Inmueble 33 zona  Norte / Equipetrol
# Guardando: Inmueble 34 zona  Norte
# Guardando: Inmueble 35 zona  Norte
# Guardando: Inmueble 36 zona  Norte / Remanso
# Guardando: Inmueble 37 zona  Centro
# Guardando: Inmueble 38 zona  Urubó
# Guardando: Inmueble 39 zona  Sur
# Guardando: Inmueble 40 zona  Norte
# Guardando: Inmueble 41 zona  Norte
# Guardando: Inmueble 42 zona  Norte / Remanso
# Guardando: Inmueble 43 zona  Norte / Remanso
# Guardando: Inmueble 44 zona  Este
# Guardando: Inmueble 45 zona  Oeste / Las palmas
# Guardando: Inmueble 46 zona  Urubó
# Guardando: Inmueble 47 zona  Norte
# Guardando: Inmueble 48 zona  Norte / Equipetrol
# Guardando: Inmueble 49 zona  Este
# Guardando: Inmueble 50 zona  Norte / Remanso
# Guardando: Inmueble 51 zona  Norte / Remanso
# Guardando: Inmueble 52 zona  Urubó
# Guardando: Inmueble 53 zona  Este
# Guardando: Inmueble 54 zona  Norte
# Guardando: Inmueble 55 zona  Norte
# Guardando: Inmueble 56 zona  Norte / Remanso
# Guardando: Inmueble 57 zona  Urubó
# Guardando: Inmueble 58 zona  Sur
# Guardando: Inmueble 59 zona  Sur
# Guardando: Inmueble 60 zona  Norte / Equipetrol
# Guardando: Inmueble 61 zona  Norte
# Guardando: Inmueble 62 zona  Norte / Hamacas
# Guardando: Inmueble 63 zona  Norte
# Guardando: Inmueble 64 zona  Centro
# Guardando: Inmueble 65 zona  Norte
# Guardando: Inmueble 66 zona  Urubó
# Guardando: Inmueble 67 zona  Oeste
# Guardando: Inmueble 68 zona  Norte / Remanso
# Guardando: Inmueble 69 zona  Urubó
# Guardando: Inmueble 70 zona  Oeste / Urbari
# Guardando: Inmueble 71 zona  Sur
# Guardando: Inmueble 72 zona  Norte
# Guardando: Inmueble 73 zona  Norte
# Guardando: Inmueble 74 zona  Sur
# Guardando: Inmueble 75 zona  Sur
# Guardando: Inmueble 76 zona  Oeste / Las palmas
# Guardando: Inmueble 77 zona  Este
# Guardando: Inmueble 78 zona  Norte
# Guardando: Inmueble 79 zona  Norte
# Guardando: Inmueble 80 zona  Oeste
# Guardando: Inmueble 81 zona  Norte
# Guardando: Inmueble 82 zona  Norte
# Guardando: Inmueble 83 zona  Norte
# Guardando: Inmueble 84 zona  Oeste
# Guardando: Inmueble 85 zona  Norte
# Guardando: Inmueble 86 zona  Norte
# Guardando: Inmueble 87 zona  Sur
# Guardando: Inmueble 88 zona  Norte
# Guardando: Inmueble 89 zona  Centro
# Guardando: Inmueble 90 zona  Centro
# Guardando: Inmueble 91 zona  Oeste
# Guardando: Inmueble 92 zona  Norte
# Guardando: Inmueble 93 zona  Norte
# Guardando: Inmueble 94 zona  Norte / Equipetrol
# Guardando: Inmueble 95 zona  Oeste
# Guardando: Inmueble 96 zona  Urubó
# Guardando: Inmueble 97 zona  Oeste / Las palmas
# Guardando: Inmueble 98 zona  Norte
# Guardando: Inmueble 99 zona  Oeste
# Guardando: Inmueble 100 zona  Norte
# Guardando: Inmueble 101 zona  Oeste / Urbari
# Guardando: Inmueble 102 zona  Sur
# Guardando: Inmueble 103 zona  Sur
# Guardando: Inmueble 104 zona  Norte
# Guardando: Inmueble 105 zona  Este
# Guardando: Inmueble 106 zona  Centro
# Guardando: Inmueble 107 zona  Urubó
# Guardando: Inmueble 108 zona  Norte
# Guardando: Inmueble 109 zona  Norte
# Guardando: Inmueble 110 zona  Oeste
# Guardando: Inmueble 111 zona  Oeste
# Guardando: Inmueble 112 zona  Urubó
# Guardando: Inmueble 113 zona  Sur
# Guardando: Inmueble 114 zona  Centro
# Guardando: Inmueble 115 zona  Norte
# Guardando: Inmueble 116 zona  Oeste
# Guardando: Inmueble 117 zona  Este
# Guardando: Inmueble 118 zona  Centro
# Guardando: Inmueble 119 zona  Norte / Equipetrol
# Guardando: Inmueble 120 zona  Este
# Guardando: Inmueble 121 zona  Norte
# Guardando: Inmueble 122 zona  Este
# Guardando: Inmueble 123 zona  Este
# Guardando: Inmueble 124 zona  Centro
# Guardando: Inmueble 125 zona  Norte
# Guardando: Inmueble 126 zona  Sur / Polanco
# Guardando: Inmueble 127 zona  Este
# Guardando: Inmueble 128 zona  Oeste
# Guardando: Inmueble 129 zona  Norte
# Guardando: Inmueble 130 zona  Oeste
# Guardando: Inmueble 131 zona  Este
# Guardando: Inmueble 132 zona  Sur
# Guardando: Inmueble 133 zona  Norte / Hamacas
# Guardando: Inmueble 134 zona  Norte
# Guardando: Inmueble 135 zona  Norte
# Guardando: Inmueble 136 zona  Este
# Guardando: Inmueble 137 zona  Urubó
# Guardando: Inmueble 138 zona  Este
# Guardando: Inmueble 139 zona  Norte / Remanso
# Guardando: Inmueble 140 zona  Norte / Remanso
# Guardando: Inmueble 141 zona  Este
# Guardando: Inmueble 142 zona  Sur
# Guardando: Inmueble 143 zona  Este
# Guardando: Inmueble 144 zona  Norte
# Guardando: Inmueble 145 zona
# Guardando: Inmueble 146 zona  Norte
# Guardando: Inmueble 147 zona  Urubó
# Guardando: Inmueble 148 zona  Oeste
# Guardando: Inmueble 149 zona  Norte / Remanso
# Guardando: Inmueble 150 zona  Norte
# Guardando: Inmueble 151 zona  Urubó
# Guardando: Inmueble 152 zona  Este
# Guardando: Inmueble 153 zona  Norte
# Guardando: Inmueble 154 zona  Norte / Remanso
# Guardando: Inmueble 155 zona  Norte
# Guardando: Inmueble 156 zona  Oeste
# Guardando: Inmueble 157 zona  Oeste
# Guardando: Inmueble 158 zona  Norte
# Guardando: Inmueble 159 zona  Norte / Hamacas
# Guardando: Inmueble 160 zona  Norte
# Guardando: Inmueble 161 zona  Centro
# Guardando: Inmueble 162 zona  Norte
# Guardando: Inmueble 163 zona  Norte
# Guardando: Inmueble 164 zona  Oeste
# Guardando: Inmueble 165 zona  Sur
# Guardando: Inmueble 166 zona  Norte / Remanso
# Guardando: Inmueble 167 zona  Norte
# Guardando: Inmueble 168 zona  Norte / Hamacas
# Guardando: Inmueble 169 zona  Norte
# Guardando: Inmueble 170 zona  Norte
# Guardando: Inmueble 171 zona  Norte / Remanso
# Guardando: Inmueble 172 zona  Norte
# Guardando: Inmueble 173 zona  Oeste
# Guardando: Inmueble 174 zona  Centro
# Guardando: Inmueble 175 zona  Este
# Guardando: Inmueble 176 zona  Norte
# Guardando: Inmueble 177 zona  Norte
# Guardando: Inmueble 178 zona  Norte / Remanso
# Guardando: Inmueble 179 zona  Este
# Guardando: Inmueble 180 zona  Sur
# Guardando: Inmueble 181 zona  Oeste
# Guardando: Inmueble 182 zona  Urubó
# Guardando: Inmueble 183 zona  Urubó
# Guardando: Inmueble 184 zona  Norte / Remanso
# Guardando: Inmueble 185 zona  Sur
# Guardando: Inmueble 186 zona  Norte
# Guardando: Inmueble 187 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 188 zona  Oeste
# Guardando: Inmueble 189 zona  Sur
# Guardando: Inmueble 190 zona  Oeste / Las palmas
# Guardando: Inmueble 191 zona  Oeste
# Guardando: Inmueble 192 zona  Norte
# Guardando: Inmueble 193 zona  Norte
# Guardando: Inmueble 194 zona  Norte / Equipetrol
# Guardando: Inmueble 195 zona  Norte
# Guardando: Inmueble 196 zona  Urubó
# Guardando: Inmueble 197 zona  Sur
# Guardando: Inmueble 198 zona  Centro
# Guardando: Inmueble 199 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 200 zona  Sur
# Guardando: Inmueble 201 zona  Norte
# Guardando: Inmueble 202 zona  Oeste
# Guardando: Inmueble 203 zona  Norte / Remanso
# Guardando: Inmueble 204 zona  Norte
# Guardando: Inmueble 205 zona  Sur
# Guardando: Inmueble 206 zona  Oeste / Urbari
# Guardando: Inmueble 207 zona  Norte / Remanso
# Guardando: Inmueble 208 zona  Norte
# Guardando: Inmueble 209 zona  Centro
# Guardando: Inmueble 210 zona  Norte / Equipetrol
# Guardando: Inmueble 211 zona  Oeste / Urbari
# Guardando: Inmueble 212 zona  Norte
# Guardando: Inmueble 213 zona  Norte
# Guardando: Inmueble 214 zona  Urubó
# Guardando: Inmueble 215 zona  Norte
# Guardando: Inmueble 216 zona  Centro
# Guardando: Inmueble 217 zona  Norte
# Guardando: Inmueble 218 zona  Norte
# Guardando: Inmueble 219 zona  Norte / Remanso
# Guardando: Inmueble 220 zona  Oeste
# Guardando: Inmueble 221 zona  Este
# Guardando: Inmueble 222 zona  Oeste
# Guardando: Inmueble 223 zona  Oeste
# Guardando: Inmueble 224 zona  Norte / Equipetrol
# Guardando: Inmueble 225 zona  Urubó
# Guardando: Inmueble 226 zona  Norte
# Guardando: Inmueble 227 zona  Sur
# Guardando: Inmueble 228 zona  Sur
# Guardando: Inmueble 229 zona  Este
# Guardando: Inmueble 230 zona  Norte
# Guardando: Inmueble 231 zona  Centro
# Guardando: Inmueble 232 zona  Sur
# Guardando: Inmueble 233 zona  Norte / Remanso
# Guardando: Inmueble 234 zona  Norte / Remanso
# Guardando: Inmueble 235 zona  Norte
# Guardando: Inmueble 236 zona  Norte / Equipetrol
# Guardando: Inmueble 237 zona  Centro
# Guardando: Inmueble 238 zona  Norte
# Guardando: Inmueble 239 zona  Este
# Guardando: Inmueble 240 zona  Oeste
# Guardando: Inmueble 241 zona  Norte
# Guardando: Inmueble 242 zona  Oeste / Las palmas
# Guardando: Inmueble 243 zona  Norte
# Guardando: Inmueble 244 zona  Sur
# Guardando: Inmueble 245 zona  Oeste
# Guardando: Inmueble 246 zona  Oeste
# Guardando: Inmueble 247 zona  Norte / Equipetrol
# Guardando: Inmueble 248 zona  Norte
# Guardando: Inmueble 249 zona  Sur
# Guardando: Inmueble 250 zona  Urubó
# Guardando: Inmueble 251 zona  Urubó
# Guardando: Inmueble 252 zona  Norte / Hamacas
# Guardando: Inmueble 253 zona  Sur
# Guardando: Inmueble 254 zona  Oeste / Urbari
# Guardando: Inmueble 255 zona  Norte
# Guardando: Inmueble 256 zona  Norte
# Guardando: Inmueble 257 zona  Norte
# Guardando: Inmueble 258 zona  Norte
# Guardando: Inmueble 259 zona  Norte
# Guardando: Inmueble 260 zona  Oeste
# Guardando: Inmueble 261 zona  Oeste
# Guardando: Inmueble 262 zona  Sur
# Guardando: Inmueble 263 zona  Norte
# Guardando: Inmueble 264 zona  Sur
# Guardando: Inmueble 265 zona  Urubó
# Guardando: Inmueble 266 zona  Este
# Guardando: Inmueble 267 zona  Norte
# Guardando: Inmueble 268 zona  Centro
# Guardando: Inmueble 269 zona  Norte / Remanso
# Guardando: Inmueble 270 zona  Urubó
# Guardando: Inmueble 271 zona  Norte
# Guardando: Inmueble 272 zona  Sur
# Guardando: Inmueble 273 zona  Centro
# Guardando: Inmueble 274 zona  Oeste
# Guardando: Inmueble 275 zona  Urubó
# Guardando: Inmueble 276 zona  Norte
# Guardando: Inmueble 277 zona  Centro
# Guardando: Inmueble 278 zona  Norte
# Guardando: Inmueble 279 zona  Urubó
# Guardando: Inmueble 280 zona  Centro
# Guardando: Inmueble 281 zona  Norte
# Guardando: Inmueble 282 zona  Norte / Remanso
# Guardando: Inmueble 283 zona  Norte
# Guardando: Inmueble 284 zona  Oeste
# Guardando: Inmueble 285 zona  Norte
# Guardando: Inmueble 286 zona  Este
# Guardando: Inmueble 287 zona  Este
# Guardando: Inmueble 288 zona  Oeste
# Guardando: Inmueble 289 zona  Norte
# Guardando: Inmueble 290 zona  Urubó
# Guardando: Inmueble 291 zona  Norte
# Guardando: Inmueble 292 zona  Norte
# Guardando: Inmueble 293 zona  Urubó
# Guardando: Inmueble 294 zona  Norte / Remanso
# Guardando: Inmueble 295 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 296 zona  Oeste / Las palmas
# Guardando: Inmueble 297 zona  Norte
# Guardando: Inmueble 298 zona  Oeste / Urbari
# Guardando: Inmueble 299 zona  Norte
# Guardando: Inmueble 300 zona  Oeste
# Guardando: Inmueble 301 zona  Este
# Guardando: Inmueble 302 zona  Norte
# Guardando: Inmueble 303 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 304 zona  Sur
# Guardando: Inmueble 305 zona  Sur
# Guardando: Inmueble 306 zona  Norte
# Guardando: Inmueble 307 zona  Norte / Remanso
# Guardando: Inmueble 308 zona  Norte / Hamacas
# Guardando: Inmueble 309 zona  Norte
# Guardando: Inmueble 310 zona  Norte / Remanso
# Guardando: Inmueble 311 zona  Este
# Guardando: Inmueble 312 zona  Norte
# Guardando: Inmueble 313 zona  Centro
# Guardando: Inmueble 314 zona  Sur
# Guardando: Inmueble 315 zona  Este
# Guardando: Inmueble 316 zona  Urubó
# Guardando: Inmueble 317 zona  Urubó
# Guardando: Inmueble 318 zona  Oeste
# Guardando: Inmueble 319 zona  Norte
# Guardando: Inmueble 320 zona  Norte
# Guardando: Inmueble 321 zona  Sur
# Guardando: Inmueble 322 zona  Oeste / Urbari
# Guardando: Inmueble 323 zona  Norte
# Guardando: Inmueble 324 zona  Norte
# Guardando: Inmueble 325 zona  Norte / Remanso
# Guardando: Inmueble 326 zona  Sur / Polanco
# Guardando: Inmueble 327 zona  Urubó
# Guardando: Inmueble 328 zona  Norte / Equipetrol
# Guardando: Inmueble 329 zona  Norte
# Guardando: Inmueble 330 zona  Este
# Guardando: Inmueble 331 zona  Norte / Hamacas
# Guardando: Inmueble 332 zona  Norte / Remanso
# Guardando: Inmueble 333 zona  Centro
# Guardando: Inmueble 334 zona  Norte
# Guardando: Inmueble 335 zona  Oeste
# Guardando: Inmueble 336 zona  Norte
# Guardando: Inmueble 337 zona  Sur
# Guardando: Inmueble 338 zona  Norte / Equipetrol
# Guardando: Inmueble 339 zona  Norte / Equipetrol
# Guardando: Inmueble 340 zona  Norte
# Guardando: Inmueble 341 zona  Oeste
# Guardando: Inmueble 342 zona  Norte / Equipetrol
# Guardando: Inmueble 343 zona  Sur
# Guardando: Inmueble 344 zona  Centro
# Guardando: Inmueble 345 zona  Oeste
# Guardando: Inmueble 346 zona  Norte
# Guardando: Inmueble 347 zona  Norte
# Guardando: Inmueble 348 zona  Centro
# Guardando: Inmueble 349 zona  Ciudadelas
# Guardando: Inmueble 350 zona  Norte / Remanso
# Guardando: Inmueble 351 zona  Urubó
# Guardando: Inmueble 352 zona  Urubó
# Guardando: Inmueble 353 zona  Norte
# Guardando: Inmueble 354 zona  Norte
# Guardando: Inmueble 355 zona  Norte
# Guardando: Inmueble 356 zona  Este
# Guardando: Inmueble 357 zona  Norte
# Guardando: Inmueble 358 zona  Norte
# Guardando: Inmueble 359 zona  Este
# Guardando: Inmueble 360 zona  NA
# Guardando: Inmueble 361 zona  Centro
# Guardando: Inmueble 362 zona  Norte / Remanso
# Guardando: Inmueble 363 zona  Norte
# Guardando: Inmueble 364 zona  Este
# Guardando: Inmueble 365 zona  Este
# Guardando: Inmueble 366 zona  Norte
# Guardando: Inmueble 367 zona  Sur
# Guardando: Inmueble 368 zona  Norte / Equipetrol
# Guardando: Inmueble 369 zona  Norte / Remanso
# Guardando: Inmueble 370 zona  Norte
# Guardando: Inmueble 371 zona  Norte
# Guardando: Inmueble 372 zona  Este
# Guardando: Inmueble 373 zona  Urubó
# Guardando: Inmueble 374 zona  Oeste
# Guardando: Inmueble 375 zona  Sur
# Guardando: Inmueble 376 zona  Norte
# Guardando: Inmueble 377 zona  Norte / Remanso
# Guardando: Inmueble 378 zona  Oeste
# Guardando: Inmueble 379 zona  Norte
# Guardando: Inmueble 380 zona  Este
# Guardando: Inmueble 381 zona  Norte
# Guardando: Inmueble 382 zona  Norte
# Guardando: Inmueble 383 zona  Norte
# Guardando: Inmueble 384 zona  Urubó
# Guardando: Inmueble 385 zona  Urubó
# Guardando: Inmueble 386 zona  Norte / Equipetrol
# Guardando: Inmueble 387 zona  Este
# Guardando: Inmueble 388 zona  Norte
# Guardando: Inmueble 389 zona  Este
# Guardando: Inmueble 390 zona  Norte
# Guardando: Inmueble 391 zona  Norte
# Guardando: Inmueble 392 zona  Norte
# Guardando: Inmueble 393 zona  Centro
# Guardando: Inmueble 394 zona  Norte
# Guardando: Inmueble 395 zona  Norte
# Guardando: Inmueble 396 zona  Norte
# Guardando: Inmueble 397 zona  Norte
# Guardando: Inmueble 398 zona  Sur
# Guardando: Inmueble 399 zona  Urubó
# Guardando: Inmueble 400 zona  Sur
# Guardando: Inmueble 401 zona  Sur
# Guardando: Inmueble 402 zona  Norte / Remanso
# Guardando: Inmueble 403 zona  Oeste
# Guardando: Inmueble 404 zona  Oeste
# Guardando: Inmueble 405 zona  Oeste
# Guardando: Inmueble 406 zona  Norte
# Guardando: Inmueble 407 zona  Norte
# Guardando: Inmueble 408 zona  Sur
# Guardando: Inmueble 409 zona  Este
# Guardando: Inmueble 410 zona  Centro
# Guardando: Inmueble 411 zona  Urubó
# Guardando: Inmueble 412 zona  Oeste
# Guardando: Inmueble 413 zona  Centro
# Guardando: Inmueble 414 zona  Norte
# Guardando: Inmueble 415 zona  Sur
# Guardando: Inmueble 416 zona  Centro
# Guardando: Inmueble 417 zona  Urubó
# Guardando: Inmueble 418 zona  Centro
# Guardando: Inmueble 419 zona  Norte
# Guardando: Inmueble 420 zona  Oeste
# Guardando: Inmueble 421 zona  Norte
# Guardando: Inmueble 422 zona  Norte
# Guardando: Inmueble 423 zona  Urubó
# Guardando: Inmueble 424 zona  Norte
# Guardando: Inmueble 425 zona  Norte
# Guardando: Inmueble 426 zona  Norte / Remanso
# Guardando: Inmueble 427 zona  Norte
# Guardando: Inmueble 428 zona  Urubó
# Guardando: Inmueble 429 zona  Norte / Equipetrol
# Guardando: Inmueble 430 zona  Oeste
# Guardando: Inmueble 431 zona  Sur
# Guardando: Inmueble 432 zona  Oeste
# Guardando: Inmueble 433 zona  Oeste
# Guardando: Inmueble 434 zona  Norte
# Guardando: Inmueble 435 zona  Centro
# Guardando: Inmueble 436 zona  Oeste
# Guardando: Inmueble 437 zona  Sur
# Guardando: Inmueble 438 zona  Norte
# Guardando: Inmueble 439 zona  Norte
# Guardando: Inmueble 440 zona  Norte / Hamacas
# Guardando: Inmueble 441 zona  Norte
# Guardando: Inmueble 442 zona  Norte
# Guardando: Inmueble 443 zona  Centro
# Guardando: Inmueble 444 zona  Norte
# Guardando: Inmueble 445 zona  Norte
# Guardando: Inmueble 446 zona  Urubó
# Guardando: Inmueble 447 zona  Sur
# Guardando: Inmueble 448 zona  Oeste / Las palmas
# Guardando: Inmueble 449 zona  Norte / Remanso
# Guardando: Inmueble 450 zona  Urubó
# Guardando: Inmueble 451 zona  Norte
# Guardando: Inmueble 452 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 453 zona  Centro
# Guardando: Inmueble 454 zona  Urubó
# Guardando: Inmueble 455 zona  Urubó
# Guardando: Inmueble 456 zona  Este
# Guardando: Inmueble 457 zona  Oeste / Las palmas
# Guardando: Inmueble 458 zona  Norte
# Guardando: Inmueble 459 zona  Este
# Guardando: Inmueble 460 zona  Norte / Remanso
# Guardando: Inmueble 461 zona  Oeste
# Guardando: Inmueble 462 zona  Sur
# Guardando: Inmueble 463 zona  Norte / Remanso
# Guardando: Inmueble 464 zona  Norte
# Guardando: Inmueble 465 zona  Norte
# Guardando: Inmueble 466 zona  Norte
# Guardando: Inmueble 467 zona  Sur / Polanco
# Guardando: Inmueble 468 zona  Urubó
# Guardando: Inmueble 469 zona  Sur
# Guardando: Inmueble 470 zona  Norte
# Guardando: Inmueble 471 zona  Norte
# Guardando: Inmueble 472 zona  Este
# Guardando: Inmueble 473 zona  Oeste
# Guardando: Inmueble 474 zona  Oeste / Las palmas
# Guardando: Inmueble 475 zona  Oeste
# Guardando: Inmueble 476 zona  Norte / Remanso
# Guardando: Inmueble 477 zona  Oeste / Urbari
# Guardando: Inmueble 478 zona  Oeste
# Guardando: Inmueble 479 zona  Norte
# Guardando: Inmueble 480 zona  Norte
# Guardando: Inmueble 481 zona  Este
# Guardando: Inmueble 482 zona  Norte
# Guardando: Inmueble 483 zona  Norte
# Guardando: Inmueble 484 zona  Norte
# Guardando: Inmueble 485 zona  Norte
# Guardando: Inmueble 486 zona  Centro
# Guardando: Inmueble 487 zona  Norte
# Guardando: Inmueble 488 zona  Este
# Guardando: Inmueble 489 zona  Sur
# Guardando: Inmueble 490 zona  Norte
# Guardando: Inmueble 491 zona  Oeste / Las palmas
# Guardando: Inmueble 492 zona  Norte / Remanso
# Guardando: Inmueble 493 zona  Oeste
# Guardando: Inmueble 494 zona  Este
# Guardando: Inmueble 495 zona  Sur
# Guardando: Inmueble 496 zona  Sur
# Guardando: Inmueble 497 zona  Centro
# Guardando: Inmueble 498 zona  Norte / Hamacas
# Guardando: Inmueble 499 zona  Urubó
# Guardando: Inmueble 500 zona  Oeste
# Guardando: Inmueble 501 zona  Sur
# Guardando: Inmueble 502 zona  Urubó
# Guardando: Inmueble 503 zona  Sur
# Guardando: Inmueble 504 zona  Este
# Guardando: Inmueble 505 zona  Centro
# Guardando: Inmueble 506 zona  Oeste
# Guardando: Inmueble 507 zona  Sur
# Guardando: Inmueble 508 zona  Norte
# Guardando: Inmueble 509 zona  Norte
# Guardando: Inmueble 510 zona  Norte / Equipetrol
# Guardando: Inmueble 511 zona  Norte / Remanso
# Guardando: Inmueble 512 zona  Centro
# Guardando: Inmueble 513 zona  Norte / Hamacas
# Guardando: Inmueble 514 zona  Ciudadelas
# Guardando: Inmueble 515 zona  Este
# Guardando: Inmueble 516 zona  Norte
# Guardando: Inmueble 517 zona  Este
# Guardando: Inmueble 518 zona  Urubó
# Guardando: Inmueble 519 zona  Norte
# Guardando: Inmueble 520 zona  Norte
# Guardando: Inmueble 521 zona  Norte / Equipetrol
# Guardando: Inmueble 522 zona  Norte / Remanso
# Guardando: Inmueble 523 zona  Sur
# Guardando: Inmueble 524 zona  Norte
# Guardando: Inmueble 525 zona  Norte / Remanso
# Guardando: Inmueble 526 zona  Centro
# Guardando: Inmueble 527 zona  Norte
# Guardando: Inmueble 528 zona  Norte
# Guardando: Inmueble 529 zona  Norte / Remanso
# Guardando: Inmueble 530 zona  Este
# Guardando: Inmueble 531 zona  Sur
# Guardando: Inmueble 532 zona  Norte / Remanso
# Guardando: Inmueble 533 zona  Centro
# Guardando: Inmueble 534 zona  Norte
# Guardando: Inmueble 535 zona  Norte
# Guardando: Inmueble 536 zona  Norte / Equipetrol
# Guardando: Inmueble 537 zona  Norte
# Guardando: Inmueble 538 zona  Norte / Equipetrol
# Guardando: Inmueble 539 zona  Urubó
# Guardando: Inmueble 540 zona  Norte
# Guardando: Inmueble 541 zona  Este
# Guardando: Inmueble 542 zona  Urubó
# Guardando: Inmueble 543 zona  Sur
# Guardando: Inmueble 544 zona  Norte / Remanso
# Guardando: Inmueble 545 zona  Norte / Remanso
# Guardando: Inmueble 546 zona  Norte
# Guardando: Inmueble 547 zona  Sur
# Guardando: Inmueble 548 zona  Norte
# Guardando: Inmueble 549 zona  Centro
# Guardando: Inmueble 550 zona  Oeste
# Guardando: Inmueble 551 zona  Sur
# Guardando: Inmueble 552 zona  Norte
# Guardando: Inmueble 553 zona  Norte
# Guardando: Inmueble 554 zona  Urubó
# Guardando: Inmueble 555 zona  Oeste
# Guardando: Inmueble 556 zona  Norte / Equipetrol
# Guardando: Inmueble 557 zona  Este
# Guardando: Inmueble 558 zona  Este
# Guardando: Inmueble 559 zona  Sur
# Guardando: Inmueble 560 zona  Sur
# Guardando: Inmueble 561 zona  Centro
# Guardando: Inmueble 562 zona  Sur
# Guardando: Inmueble 563 zona  Urubó
# Guardando: Inmueble 564 zona  Norte
# Guardando: Inmueble 565 zona  Oeste
# Guardando: Inmueble 566 zona  Sur
# Guardando: Inmueble 567 zona  Norte
# Guardando: Inmueble 568 zona  Oeste / Las palmas
# Guardando: Inmueble 569 zona  Norte
# Guardando: Inmueble 570 zona  Norte
# Guardando: Inmueble 571 zona  Norte / Remanso
# Guardando: Inmueble 572 zona  Este
# Guardando: Inmueble 573 zona  Norte / Remanso
# Guardando: Inmueble 574 zona  Sur
# Guardando: Inmueble 575 zona  Norte
# Guardando: Inmueble 576 zona  Norte
# Guardando: Inmueble 577 zona  Este
# Guardando: Inmueble 578 zona  Norte / Remanso
# Guardando: Inmueble 579 zona  Sur
# Guardando: Inmueble 580 zona  Norte
# Guardando: Inmueble 581 zona  Urubó
# Guardando: Inmueble 582 zona  Norte
# Guardando: Inmueble 583 zona  Sur
# Guardando: Inmueble 584 zona  Urubó
# Guardando: Inmueble 585 zona  Norte
# Guardando: Inmueble 586 zona  Norte
# Guardando: Inmueble 587 zona  Norte / Remanso
# Guardando: Inmueble 588 zona  Este
# Guardando: Inmueble 589 zona  Norte
# Guardando: Inmueble 590 zona  Sur
# Guardando: Inmueble 591 zona  Norte
# Guardando: Inmueble 592 zona  Norte
# Guardando: Inmueble 593 zona  Norte
# Guardando: Inmueble 594 zona  Norte
# Guardando: Inmueble 595 zona  Norte
# Guardando: Inmueble 596 zona  Centro
# Guardando: Inmueble 597 zona  Urubó
# Guardando: Inmueble 598 zona  Norte
# Guardando: Inmueble 599 zona  Norte
# Guardando: Inmueble 600 zona  Centro
# Guardando: Inmueble 601 zona  Norte
# Guardando: Inmueble 602 zona  Oeste
# Guardando: Inmueble 603 zona  Oeste
# Guardando: Inmueble 604 zona  Norte / Remanso
# Guardando: Inmueble 605 zona  Ciudadelas
# Guardando: Inmueble 606 zona  Oeste
# Guardando: Inmueble 607 zona  Centro
# Guardando: Inmueble 608 zona  Norte / Remanso
# Guardando: Inmueble 609 zona  Oeste
# Guardando: Inmueble 610 zona  Norte
# Guardando: Inmueble 611 zona  Urubó
# Guardando: Inmueble 612 zona  Este
# Guardando: Inmueble 613 zona  Urubó
# Guardando: Inmueble 614 zona  Sur
# Guardando: Inmueble 615 zona  Norte / Remanso
# Guardando: Inmueble 616 zona  Este
# Guardando: Inmueble 617 zona  Norte
# Guardando: Inmueble 618 zona  Oeste
# Guardando: Inmueble 619 zona  Norte / Remanso
# Guardando: Inmueble 620 zona  Oeste / Urbari
# Guardando: Inmueble 621 zona  Norte
# Guardando: Inmueble 622 zona  Oeste
# Guardando: Inmueble 623 zona  Oeste
# Guardando: Inmueble 624 zona  Norte
# Guardando: Inmueble 625 zona  Norte / Remanso
# Guardando: Inmueble 626 zona  Norte / Hamacas
# Guardando: Inmueble 627 zona  Norte / Equipetrol
# Guardando: Inmueble 628 zona  Norte
# Guardando: Inmueble 629 zona  Norte
# Guardando: Inmueble 630 zona  Norte
# Guardando: Inmueble 631 zona  Norte
# Guardando: Inmueble 632 zona  Norte / Equipetrol
# Guardando: Inmueble 633 zona  Norte
# Guardando: Inmueble 634 zona  Centro
# Guardando: Inmueble 635 zona  Norte / Equipetrol
# Guardando: Inmueble 636 zona  Urubó
# Guardando: Inmueble 637 zona  Sur / Polanco
# Guardando: Inmueble 638 zona  Norte / Remanso
# Guardando: Inmueble 639 zona  Urubó
# Guardando: Inmueble 640 zona  Centro
# Guardando: Inmueble 641 zona  Urubó
# Guardando: Inmueble 642 zona  Este
# Guardando: Inmueble 643 zona  Norte / Equipetrol
# Guardando: Inmueble 644 zona  Centro
# Guardando: Inmueble 645 zona  Norte
# Guardando: Inmueble 646 zona  Oeste
# Guardando: Inmueble 647 zona  Norte
# Guardando: Inmueble 648 zona  Centro
# Guardando: Inmueble 649 zona  Norte
# Guardando: Inmueble 650 zona  Centro
# Guardando: Inmueble 651 zona  Sur
# Guardando: Inmueble 652 zona  Norte
# Guardando: Inmueble 653 zona  Urubó
# Guardando: Inmueble 654 zona  Norte / Remanso
# Guardando: Inmueble 655 zona  Norte / Equipetrol
# Guardando: Inmueble 656 zona  Sur
# Guardando: Inmueble 657 zona  Centro
# Guardando: Inmueble 658 zona  Urubó
# Guardando: Inmueble 659 zona  Norte
# Guardando: Inmueble 660 zona  Sur
# Guardando: Inmueble 661 zona  Urubó
# Guardando: Inmueble 662 zona  Oeste
# Guardando: Inmueble 663 zona  Norte
# Guardando: Inmueble 664 zona  Sur
# Guardando: Inmueble 665 zona  Oeste / Las palmas
# Guardando: Inmueble 666 zona  Este
# Guardando: Inmueble 667 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 668 zona  Sur
# Guardando: Inmueble 669 zona  Centro
# Guardando: Inmueble 670 zona  Sur
# Guardando: Inmueble 671 zona  Norte
# Guardando: Inmueble 672 zona  Urubó
# Guardando: Inmueble 673 zona  Norte
# Guardando: Inmueble 674 zona  Urubó
# Guardando: Inmueble 675 zona  Oeste
# Guardando: Inmueble 676 zona  Norte
# Guardando: Inmueble 677 zona  Sur
# Guardando: Inmueble 678 zona  Sur
# Guardando: Inmueble 679 zona  Este
# Guardando: Inmueble 680 zona  Urubó
# Guardando: Inmueble 681 zona  Norte
# Guardando: Inmueble 682 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 683 zona  Norte
# Guardando: Inmueble 684 zona  Norte
# Guardando: Inmueble 685 zona  Norte
# Guardando: Inmueble 686 zona  Sur
# Guardando: Inmueble 687 zona  Norte
# Guardando: Inmueble 688 zona  Sur
# Guardando: Inmueble 689 zona  Norte
# Guardando: Inmueble 690 zona  Este
# Guardando: Inmueble 691 zona  Sur
# Guardando: Inmueble 692 zona  Norte
# Guardando: Inmueble 693 zona  Norte / Remanso
# Guardando: Inmueble 694 zona  Norte
# Guardando: Inmueble 695 zona  Oeste / Las palmas
# Guardando: Inmueble 696 zona  Sur
# Guardando: Inmueble 697 zona  Norte
# Guardando: Inmueble 698 zona  Sur
# Guardando: Inmueble 699 zona  Norte
# Guardando: Inmueble 700 zona  Norte
# Guardando: Inmueble 701 zona  Sur
# Guardando: Inmueble 702 zona  Norte / Hamacas
# Guardando: Inmueble 703 zona  Norte
# Guardando: Inmueble 704 zona  Norte
# Guardando: Inmueble 705 zona  Urubó
# Guardando: Inmueble 706 zona  Oeste
# Guardando: Inmueble 707 zona  Norte
# Guardando: Inmueble 708 zona  Este
# Guardando: Inmueble 709 zona  Sur
# Guardando: Inmueble 710 zona  Oeste / Las palmas
# Guardando: Inmueble 711 zona  Oeste
# Guardando: Inmueble 712 zona  Urubó
# Guardando: Inmueble 713 zona  Norte / Equipetrol
# Guardando: Inmueble 714 zona  Norte
# Guardando: Inmueble 715 zona  Urubó
# Guardando: Inmueble 716 zona  Sur
# Guardando: Inmueble 717 zona  Norte / Equipetrol
# Guardando: Inmueble 718 zona  Este
# Guardando: Inmueble 719 zona  Este
# Guardando: Inmueble 720 zona  Norte / Equipetrol
# Guardando: Inmueble 721 zona  Sur
# Guardando: Inmueble 722 zona  Norte / Remanso
# Guardando: Inmueble 723 zona  Centro
# Guardando: Inmueble 724 zona  Norte
# Guardando: Inmueble 725 zona  Sur
# Guardando: Inmueble 726 zona  Norte
# Guardando: Inmueble 727 zona  Norte
# Guardando: Inmueble 728 zona  Este
# Guardando: Inmueble 729 zona  Sur
# Guardando: Inmueble 730 zona  Norte
# Guardando: Inmueble 731 zona  Ciudadelas
# Guardando: Inmueble 732 zona  Norte
# Guardando: Inmueble 733 zona  Oeste
# Guardando: Inmueble 734 zona  Oeste
# Guardando: Inmueble 735 zona  Urubó
# Guardando: Inmueble 736 zona  Centro
# Guardando: Inmueble 737 zona  Sur
# Guardando: Inmueble 738 zona  Oeste
# Guardando: Inmueble 739 zona  Norte
# Guardando: Inmueble 740 zona  Centro
# Guardando: Inmueble 741 zona  Norte
# Guardando: Inmueble 742 zona  Sur
# Guardando: Inmueble 743 zona  Sur
# Guardando: Inmueble 744 zona  Norte / Remanso
# Guardando: Inmueble 745 zona  Centro
# Guardando: Inmueble 746 zona  Oeste / Las palmas
# Guardando: Inmueble 747 zona  Norte
# Guardando: Inmueble 748 zona  Sur
# Guardando: Inmueble 749 zona  Norte
# Guardando: Inmueble 750 zona  Urubó
# Guardando: Inmueble 751 zona  Urubó
# Guardando: Inmueble 752 zona  Este
# Guardando: Inmueble 753 zona  Norte / Equipetrol
# Guardando: Inmueble 754 zona  Norte
# Guardando: Inmueble 755 zona  Norte / Remanso
# Guardando: Inmueble 756 zona  Norte
# Guardando: Inmueble 757 zona  Sur
# Guardando: Inmueble 758 zona  Sur
# Guardando: Inmueble 759 zona  Este
# Guardando: Inmueble 760 zona  Centro
# Guardando: Inmueble 761 zona  Centro
# Guardando: Inmueble 762 zona  Urubó
# Guardando: Inmueble 763 zona  Urubó
# Guardando: Inmueble 764 zona  Centro
# Guardando: Inmueble 765 zona  Norte / Hamacas
# Guardando: Inmueble 766 zona  Este
# Guardando: Inmueble 767 zona  Centro
# Guardando: Inmueble 768 zona  Norte
# Guardando: Inmueble 769 zona  Norte / Remanso
# Guardando: Inmueble 770 zona  Norte / Remanso
# Guardando: Inmueble 771 zona  Norte
# Guardando: Inmueble 772 zona  Norte
# Guardando: Inmueble 773 zona  Norte
# Guardando: Inmueble 774 zona  Norte
# Guardando: Inmueble 775 zona  Sur
# Guardando: Inmueble 776 zona  Centro
# Guardando: Inmueble 777 zona  Oeste
# Guardando: Inmueble 778 zona  Oeste
# Guardando: Inmueble 779 zona  Oeste
# Guardando: Inmueble 780 zona  Sur / Polanco
# Guardando: Inmueble 781 zona  Norte
# Guardando: Inmueble 782 zona  Este
# Guardando: Inmueble 783 zona  Oeste / Las palmas
# Guardando: Inmueble 784 zona  Norte
# Guardando: Inmueble 785 zona  Este
# Guardando: Inmueble 786 zona  Norte
# Guardando: Inmueble 787 zona  Este
# Guardando: Inmueble 788 zona  Oeste
# Guardando: Inmueble 789 zona  Norte
# Guardando: Inmueble 790 zona  Sur
# Guardando: Inmueble 791 zona  Norte / Remanso
# Guardando: Inmueble 792 zona  Urubó
# Guardando: Inmueble 793 zona  Norte
# Guardando: Inmueble 794 zona  Norte
# Guardando: Inmueble 795 zona  Norte
# Guardando: Inmueble 796 zona  Norte
# Guardando: Inmueble 797 zona  Norte
# Guardando: Inmueble 798 zona  Este
# Guardando: Inmueble 799 zona  Este
# Guardando: Inmueble 800 zona  Oeste
# Guardando: Inmueble 801 zona  Sur
# Guardando: Inmueble 802 zona  Urubó
# Guardando: Inmueble 803 zona  Sur
# Guardando: Inmueble 804 zona  Oeste
# Guardando: Inmueble 805 zona  Norte / Equipetrol
# Guardando: Inmueble 806 zona  Norte
# Guardando: Inmueble 807 zona  Norte
# Guardando: Inmueble 808 zona  Urubó
# Guardando: Inmueble 809 zona  Centro
# Guardando: Inmueble 810 zona  Sur
# Guardando: Inmueble 811 zona  Norte
# Guardando: Inmueble 812 zona  Oeste
# Guardando: Inmueble 813 zona  Norte
# Guardando: Inmueble 814 zona  Norte
# Guardando: Inmueble 815 zona  Norte
# Guardando: Inmueble 816 zona  Oeste
# Guardando: Inmueble 817 zona  Norte
# Guardando: Inmueble 818 zona  Norte / Equipetrol
# Guardando: Inmueble 819 zona  Oeste
# Guardando: Inmueble 820 zona  Norte
# Guardando: Inmueble 821 zona  Norte / Hamacas
# Guardando: Inmueble 822 zona  Centro
# Guardando: Inmueble 823 zona  Urubó
# Guardando: Inmueble 824 zona  Urubó
# Guardando: Inmueble 825 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 826 zona  Oeste
# Guardando: Inmueble 827 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 828 zona  Norte
# Guardando: Inmueble 829 zona  Norte / Remanso
# Guardando: Inmueble 830 zona  Norte
# Guardando: Inmueble 831 zona  Norte / Equipetrol
# Guardando: Inmueble 832 zona  Norte
# Guardando: Inmueble 833 zona  Norte
# Guardando: Inmueble 834 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 835 zona  Oeste
# Guardando: Inmueble 836 zona  Este
# Guardando: Inmueble 837 zona  Norte
# Guardando: Inmueble 838 zona  Centro
# Guardando: Inmueble 839 zona  Sur
# Guardando: Inmueble 840 zona  Urubó
# Guardando: Inmueble 841 zona  Centro
# Guardando: Inmueble 842 zona  Norte
# Guardando: Inmueble 843 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 844 zona  Sur
# Guardando: Inmueble 845 zona  Centro
# Guardando: Inmueble 846 zona  Oeste
# Guardando: Inmueble 847 zona  Centro
# Guardando: Inmueble 848 zona  Norte / Equipetrol
# Guardando: Inmueble 849 zona  Norte
# Guardando: Inmueble 850 zona  Ciudadelas
# Guardando: Inmueble 851 zona  Oeste / Urbari
# Guardando: Inmueble 852 zona  Este
# Guardando: Inmueble 853 zona  Urubó
# Guardando: Inmueble 854 zona  Urubó
# Guardando: Inmueble 855 zona  Norte
# Guardando: Inmueble 856 zona  Oeste
# Guardando: Inmueble 857 zona  Sur
# Guardando: Inmueble 858 zona  Norte
# Guardando: Inmueble 859 zona  Oeste
# Guardando: Inmueble 860 zona  Norte
# Guardando: Inmueble 861 zona  Norte / Equipetrol
# Guardando: Inmueble 862 zona  Sur / Polanco
# Guardando: Inmueble 863 zona  Urubó
# Guardando: Inmueble 864 zona  Norte / Hamacas
# Guardando: Inmueble 865 zona  Este
# Guardando: Inmueble 866 zona  Oeste
# Guardando: Inmueble 867 zona  Oeste
# Guardando: Inmueble 868 zona  Sur
# Guardando: Inmueble 869 zona  Norte / Equipetrol
# Guardando: Inmueble 870 zona  Norte / Equipetrol
# Guardando: Inmueble 871 zona  Norte
# Guardando: Inmueble 872 zona  Norte
# Guardando: Inmueble 873 zona  Norte
# Guardando: Inmueble 874 zona  Este
# Guardando: Inmueble 875 zona  Norte / Remanso
# Guardando: Inmueble 876 zona  Urubó
# Guardando: Inmueble 877 zona  Norte / Remanso
# Guardando: Inmueble 878 zona  Sur
# Guardando: Inmueble 879 zona  Sur
# Guardando: Inmueble 880 zona  Norte
# Guardando: Inmueble 881 zona  Norte
# Guardando: Inmueble 882 zona  Norte
# Guardando: Inmueble 883 zona  Este
# Guardando: Inmueble 884 zona  Oeste / Doble via la guardia
# Guardando: Inmueble 885 zona  Norte
# Guardando: Inmueble 886 zona  Norte
# Guardando: Inmueble 887 zona  Este
# Guardando: Inmueble 888 zona  Centro
# Guardando: Inmueble 889 zona  Centro
# Guardando: Inmueble 890 zona  Norte
# Guardando: Inmueble 891 zona  Oeste / Las palmas
# Guardando: Inmueble 892 zona  Este
# Guardando: Inmueble 893 zona  Norte
# Guardando: Inmueble 894 zona  Oeste
# Guardando: Inmueble 895 zona  Centro
# Guardando: Inmueble 896 zona  Norte
# Guardando: Inmueble 897 zona  Norte

# %% [markdown]
# ### Formato y Exportación
# Por último, daremos formato a nuestro datos y los exportaremos para manipularlos en otra ocasión

# %%
df = pd.DataFrame(lista_items)
print(df.head(10))
df.to_csv('infocasas.csv', index = False)
# Out:
#                                               titulo   tipo dormitorios baños  \
# 0  Casa En Venta Condominio Valle Del Cartago / K...  Casas           3     2
# 1       Casa En Venta En El Urubo - Cond. Rio Sierra  Casas           4     3
# 2    Casa En Venta Sobre Avenida Con Local Comercial  Casas           4     2
# 3  Casa En Venta En Colinas Del Urubo Sector 1 La...  Casas           5     3
# 4               Hermosa Casa Quinta Zona Urubo Trejo  Casas           4     3
# 5                                                 NA     NA          NA    NA
# 6  Casa En Venta En El Condominio La Pradera, Zon...  Casas           4     3
# 7                          Casa De Lujo En Venta !!!  Casas           5     3
# 8  En Equipetrol - Amplia Casa De 4 Dormts Ideal ...  Casas           4     3
# 9  Alquiler Casa Grande Comercial Zona Céntrica C...  Casas           5     3
#
#   garajes   m2                zona   precio
# 0       2  272               Norte  156.000
# 1       3  721               Urubó  398.000
# 2       2  300                 Sur   95.000
# 3       3  475               Oeste  499.000
# 4       0  330               Urubó  300.000
# 5       0   NA                  NA       NA
# 6       3  317     Norte / Remanso  220.000
# 7       3  382               Norte  355.000
# 8       2  260  Norte / Equipetrol  279.000
# 9       3  630              Centro  600.000
